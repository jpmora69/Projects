# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt 
from bokeh.charts import Bar, output_file, show
from bokeh.charts.attributes import cat
# %matplotlib inline
csfont = {'fontname':'Arial'}
import plotly.plotly as py
import plotly.graph_objs as go
#init_notebook_mode(connected=True)
py.sign_in('jpmora', '63aq6fwdpj')

# %%
datadog = pd.read_excel('NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx')

# %%
datadog
# Out:
#        Owner Zip Code            Animal Name Animal Gender  \
# 0               10013                  Bilal             M
# 1               10025                  Buddy             M
# 2               10013                    Ali             M
# 3               10013                  Queen             F
# 4               10035       Paige Sable Orta             F
# 5               10465                   Yogi             M
# 6               10013              Chewbacca             F
# 7               10013             IAN                    M
# 8               10028                   Lola             F
# 9               11232                 muneca             F
# 10              10022              Elizabeth             F
# 11              11209                 Benson             M
# 12              10025                 Dottie             F
# 13              11215          Lucy Moo Jung             F
# 14              10025  Apple Wazowski Panwar             M
# 15              10312                  Buddy             M
# 16              11220                  Ricky             M
# 17              10002                  Avery             F
# 18              10025                  Sarah             F
# 19              10308                 Sophie             F
# 20              11201                Massimo             M
# 21              11218            Bess Walker             F
# 22              11208                   Bigs             M
# 23              10003                  Lemmy             F
# 24              11238               June Bug             F
# 25              10463                 Murphy             M
# 26              11215               HEIDI-BO             F
# 27              10011             OTIS                   F
# 28              10011               Logan                M
# 29              10022                   Lola             F
# ...               ...                    ...           ...
# 81914           10462                  Shiro             M
# 81915           11238                   Milo             M
# 81916           10302             BOO                    F
# 81917           10027                   YUKI             M
# 81918           10011                   Otto             M
# 81919           10003                 Maggie             F
# 81920           11420                    rex             M
# 81921           10065            Hugo Djuric             M
# 81922           10001               Lucy Lee             F
# 81923           11102              Guinness              M
# 81924           11385                 Maddie             F
# 81925           10463                  Leila             F
# 81926           10280                  ROCKY             M
# 81927           10452                boo boo             F
# 81928           10027                  Caper             F
# 81929           11234                  Simba             M
# 81930           11213                   Erie             M
# 81931           11385                  Logan             M
# 81932           11237                  Sadie             F
# 81933           10280                   emmy             F
# 81934           11235                Unknown             F
# 81935           10028                   Kira             F
# 81936           11103                    joe             M
# 81937           10009                Charlie             M
# 81938           10001                   Lucy             F
# 81939           10001          Cheeseburger              M
# 81940           10021                   Jack             M
# 81941           10032                Petunia             F
# 81942           10310                    Max             M
# 81943           10016                 Sirius             F
#
#                               Primary Breed            Secondary Breed  \
# 0                      Australian Cattledog                        NaN
# 1                                   Unknown                   Cockapoo
# 2                                   Basenji                        NaN
# 3                          Akita Crossbreed                        NaN
# 4      American Pit Bull Mix / Pit Bull Mix                        NaN
# 5                                     Boxer                        NaN
# 6             Labrador Retriever Crossbreed                        NaN
# 7                                   Unknown            GREYHOUND TER X
# 8                                   Maltese                        NaN
# 9                                    Beagle                        NaN
# 10            Cavalier King Charles Spaniel                        NaN
# 11                                    Boxer                        NaN
# 12                         Poodle, Standard                        NaN
# 13          Dachshund Smooth Coat Miniature                        NaN
# 14                                 Havanese                        NaN
# 15                             Bull Terrier                        NaN
# 16                      German Shepherd Dog                        NaN
# 17       American Pit Bull Terrier/Pit Bull                        NaN
# 18                                  Unknown  Boxer/Pharaoh Hound/Other
# 19                                    Boxer                        NaN
# 20                         Bull Dog, French                        NaN
# 21                                   Beagle                        NaN
# 22       American Pit Bull Terrier/Pit Bull                        NaN
# 23                        Yorkshire Terrier                        NaN
# 24            Cavalier King Charles Spaniel                        NaN
# 25     American Pit Bull Mix / Pit Bull Mix                        NaN
# 26                    Dachshund Smooth Coat                        NaN
# 27                                  Unknown            SEALYHAM TERR
# 28                                  Unknown            SealyhamTerrier
# 29                       Miniature Pinscher                        NaN
# ...                                     ...                        ...
# 81914                               Maltese                        NaN
# 81915                       Wheaton Terrier                        NaN
# 81916                               Unknown            BOGLEN TERRIER
# 81917                          Bichon Frise                        NaN
# 81918                               Unknown          Lagotto Romagnolo
# 81919         Labrador Retriever Crossbreed                        NaN
# 81920                     Yorkshire Terrier                        NaN
# 81921                              Havanese                        NaN
# 81922                              Havanese                        NaN
# 81923                  Dachshund Crossbreed                        NaN
# 81924                     Yorkshire Terrier                        NaN
# 81925                     Yorkshire Terrier                        NaN
# 81926                              Shih Tzu                        NaN
# 81927                               Unknown                        NaN
# 81928                          Basset Hound                        NaN
# 81929                   German Shepherd Dog                        NaN
# 81930                               Unknown                        NaN
# 81931                        Siberian Husky                        NaN
# 81932                      Golden Retriever                        NaN
# 81933                  Chihuahua Crossbreed                        NaN
# 81934            German Shepherd Crossbreed                        NaN
# 81935                                Beagle                        NaN
# 81936                  Chihuahua Crossbreed                        NaN
# 81937         Cavalier King Charles Spaniel                        NaN
# 81938                                   Pug                        NaN
# 81939                                   Pug                        NaN
# 81940                               Unknown                        NaN
# 81941                            Lhasa Apso                        NaN
# 81942                        Cocker Spaniel                        NaN
# 81943            German Shepherd Crossbreed                        NaN
#
#       Animal Dominant Color Animal Secondary Color Animal Third Color  \
# 0                      Rust                    NaN                NaN
# 1                     BLOND                  WHITE                NaN
# 2                     Black                    NaN                NaN
# 3                  Charcoal                    Red                NaN
# 4                     White                   Gray                NaN
# 5                       TAN                  BLACK                NaN
# 6                       RED                    NaN                NaN
# 7                     WHITE                  BLACK                NaN
# 8                   Apricot                  White                NaN
# 9                     White                  Black              Brown
# 10                    Brown                  White                NaN
# 11                  BRINDLE                    NaN                NaN
# 12                    Cream                    NaN                NaN
# 13                    White                  Black                NaN
# 14                    WHITE                  BLACK                NaN
# 15                    BLACK                  WHITE                NaN
# 16                    Black                    Tan                NaN
# 17                     Gray                    NaN                NaN
# 18                  Brindle                    NaN                NaN
# 19                    BROWN                BRINDLE                NaN
# 20                    WHITE                  BLACK                NaN
# 21                    BLACK                  BROWN              WHITE
# 22                    BROWN                  WHITE                NaN
# 23                    BLOND                   GRAY                NaN
# 24                    WHITE                  BLACK              BROWN
# 25                    BROWN                  WHITE                NaN
# 26                    Brown                  Black                NaN
# 27                    WHITE                  BLACK                NaN
# 28                    WHITE                  BROWN                NaN
# 29                    BLACK                   RUST                NaN
# ...                     ...                    ...                ...
# 81914                 WHITE                    NaN                NaN
# 81915                 BLACK                    NaN                NaN
# 81916               BRINDLE                    NaN                NaN
# 81917                 WHITE                    NaN                NaN
# 81918                ORANGE                    NaN                NaN
# 81919                 Black                    NaN                NaN
# 81920                  Blue                   Gold                NaN
# 81921                 Black                  White                NaN
# 81922                   Tan                Apricot                NaN
# 81923                 Black                    Tan                NaN
# 81924                   TAN                  BLACK                NaN
# 81925                  Blue                   Gold                NaN
# 81926                 Blond              Chocolate                NaN
# 81927                 Brown                    NaN                NaN
# 81928             Chocolate                    NaN                NaN
# 81929                 BLACK                    TAN                NaN
# 81930                 Black                    NaN                NaN
# 81931                 BLACK                  WHITE               GRAY
# 81932                 Blond                    NaN                NaN
# 81933                 Black                    NaN                NaN
# 81934                 Brown                    NaN                NaN
# 81935                 Brown                    Tan              Black
# 81936                 White                    NaN                NaN
# 81937                 Brown                  White                NaN
# 81938                  Fawn                    NaN                NaN
# 81939                  Fawn                    NaN                NaN
# 81940                 Cream                    NaN                NaN
# 81941                  GOLD                  BLACK              WHITE
# 81942                 WHITE                  BROWN                NaN
# 81943                 BROWN                    TAN              BLACK
#
#               Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0      2014-09-01 00:00:00            Yes              NaN         No
# 1      2008-04-01 00:00:00            Yes               No        Yes
# 2      2014-01-01 00:00:00             No              NaN         No
# 3      2013-04-01 00:00:00             No              NaN        Yes
# 4      2014-07-01 00:00:00             No              NaN         No
# 5      2010-09-01 00:00:00            Yes               No        Yes
# 6      2012-06-01 00:00:00            Yes               No        Yes
# 7      2006-01-01 00:00:00            Yes               No        Yes
# 8      2009-06-01 00:00:00            Yes               No        Yes
# 9      2013-05-01 00:00:00            Yes              NaN        Yes
# 10     2013-03-01 00:00:00            Yes              NaN        Yes
# 11     2010-07-01 00:00:00            Yes               No        Yes
# 12     2013-04-01 00:00:00            Yes              NaN        Yes
# 13     2014-03-01 00:00:00            Yes              NaN        Yes
# 14     2013-07-01 00:00:00            Yes               No         No
# 15     2012-10-01 00:00:00            Yes               No        Yes
# 16     2014-07-01 00:00:00             No              NaN         No
# 17     2014-06-01 00:00:00             No              NaN         No
# 18     2012-12-01 00:00:00            Yes              NaN        Yes
# 19     2011-09-01 00:00:00            Yes               No        Yes
# 20     2009-07-01 00:00:00            Yes               No        Yes
# 21     2010-09-01 00:00:00            Yes               No        Yes
# 22     2004-12-01 00:00:00            Yes               No        Yes
# 23     2005-07-01 00:00:00            Yes               No        Yes
# 24     2010-04-01 00:00:00            Yes               No        Yes
# 25     2012-01-01 00:00:00            Yes               No        Yes
# 26     2007-09-01 00:00:00            Yes               No        Yes
# 27     2001-01-01 00:00:00            Yes               No        Yes
# 28     2003-01-01 00:00:00            Yes               No         No
# 29     2006-08-01 00:00:00            Yes               No        Yes
# ...                    ...            ...              ...        ...
# 81914  2011-01-01 00:00:00            Yes               No        Yes
# 81915  2006-11-01 00:00:00            Yes               No        Yes
# 81916  2005-01-01 00:00:00            Yes               No        Yes
# 81917  2003-03-01 00:00:00            Yes               No         No
# 81918  2013-06-01 00:00:00            Yes               No        Yes
# 81919  2012-12-01 00:00:00            Yes              NaN        Yes
# 81920  2016-02-01 00:00:00            Yes              NaN         No
plt.xticks(rotation=45, fontsize=13, **csfont)
plt.yticks(fontsize=12, **csfont)
# Out:
# (array([    0.,   200.,   400.,   600.,   800.,  1000.,  1200.,  1400.,
#          1600.]), <a list of 9 Text yticklabel objects>)

# %%
topnames = datadog['Animal Name'].value_counts().nlargest(10).sort_values(ascending=False)
bar = Bar(topnames, values='Animal Name', title='10 most common names for licenced dogs in NYC', filename="bar.html", 
         color="blue", title_text_font_size='40pt', plot_width=600, plot_height=400)
bar.show()
# Out:
# C:\Users\juanpablo\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: BokehDeprecationWarning:
#
# bokeh.charts.chart.show was deprecated in Bokeh 0.11; please use bokeh.io.show instead

# %%
topnames2 = topnames.reset_index()

# %%
dogname = [
    go.Bar(
        x=topnames2['index'],
        y=topnames2['Animal Name'])
]
layout = go.Layout(title='10 most common dog names in NYC', titlefont=dict(family='Arial', size=26))
fig = go.Figure(data=dogname, layout=layout)
py.iplot(fig, filename='basic-bar')
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~jpmora/0 or inside your plot.ly account where it is named 'basic-bar'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jpmora/0.embed" height="525px" width="100%"></iframe>

# %%
sex = datadog['Animal Gender'].value_counts().nlargest(10).sort_values(ascending=False)[0:2]
bar1 = Bar(sex, values='Animal Gender', title='Gender distribution for licenced dogs in NYC', filename="bar.html", 
         color="red", title_text_font_size='40pt', plot_width=600, plot_height=400)
bar1.show()
# Out:
# C:\Users\juanpablo\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: BokehDeprecationWarning:
#
# bokeh.charts.chart.show was deprecated in Bokeh 0.11; please use bokeh.io.show instead

# %%
sex2 = sex.reset_index()

# %%
sex2
# Out:
#   index  Animal Gender
# 0     M          44431
# 1     F          37505

# %%
dogsex = [go.Bar(x=sex2['index'], y=sex2['Animal Gender'], text=['Male', 'Female']
                 , marker=dict(color='rgb(255,0,0)'), opacity=0.6)]
layout = go.Layout(title='Gender distribution for licenced dogs in NYC', titlefont=dict(family='Arial', size=26))
fig1 = go.Figure(data=dogsex, layout=layout)
py.iplot(fig1, filename='basic-bar')
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~jpmora/0 or inside your plot.ly account where it is named 'basic-bar'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jpmora/0.embed" height="525px" width="100%"></iframe>

# %%
breed = datadog['Primary Breed'].value_counts().nlargest(10).sort_values(ascending=False)
breed2 = breed.reset_index()
breed2
# Out:
#                                   index  Primary Breed
# 0                               Unknown          12898
# 1                     Yorkshire Terrier           5133
# 2                              Shih Tzu           4727
# 3                             Chihuahua           3924
# 4                               Maltese           2965
# 5                    Labrador Retriever           2874
# 6    American Pit Bull Terrier/Pit Bull           2153
# 7  American Pit Bull Mix / Pit Bull Mix           2029
# 8         Labrador Retriever Crossbreed           1864
# 9                                Beagle           1438

# %%
dogbreed = [go.Bar(x=breed2['index'], y=breed2['Primary Breed'], marker=dict(color='rgb(192,192,192)'), opacity=0.7)]
layout = go.Layout(title='Top 10 most common breeds for licenced dogs in NYC', titlefont=dict(family='Arial', size=26))
fig2 = go.Figure(data=dogbreed, layout=layout)
py.iplot(fig2, filename='basic-bar')
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~jpmora/0 or inside your plot.ly account where it is named 'basic-bar'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jpmora/0.embed" height="525px" width="100%"></iframe>

# %%
datadog.columns
# Out:
# Index([u'Owner Zip Code', u'Animal Name', u'Animal Gender', u'Primary Breed',
#        u'Secondary Breed', u'Animal Dominant Color', u'Animal Secondary Color',
#        u'Animal Third Color', u'Animal Birth', u'Spayed or Neut',
#        u'Guard or Trained', u'Vaccinated', u'Application Date',
#        u'License Issued Date', u'License Expired Date'],
#       dtype='object')

# %%
collist = datadog.columns.tolist()

# %%
remove = [u'Secondary Breed', u'Animal Secondary Color', u'Animal Third Color']

# %%
collist = [x for x in collist if x not in remove]

# %%
collist
# Out:
# [u'Owner Zip Code',
#  u'Animal Name',
#  u'Animal Gender',
#  u'Primary Breed',
#  u'Animal Dominant Color',
#  u'Animal Birth',
#  u'Spayed or Neut',
#  u'Guard or Trained',
#  u'Vaccinated',
#  u'Application Date',
#  u'License Issued Date',
#  u'License Expired Date']

# %%
datadog = datadog[collist]

# %%
datadog.head()
# Out:
#    Owner Zip Code       Animal Name Animal Gender  \
# 0           10013             BILAL             M
# 1           10025             BUDDY             M
# 2           10013               ALI             M
# 3           10013             QUEEN             F
# 4           10035  PAIGE SABLE ORTA             F
#
#                           Primary Breed Animal Dominant Color  \
# 0                  Australian Cattledog                  Rust
# 1                               Unknown                 BLOND
# 2                               Basenji                 Black
# 3                      Akita Crossbreed              Charcoal
# 4  American Pit Bull Mix / Pit Bull Mix                 White
#
#           Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0  2014-09-01 00:00:00            Yes              NaN         No
# 1  2008-04-01 00:00:00            Yes               No        Yes
# 2  2014-01-01 00:00:00             No              NaN         No
# 3  2013-04-01 00:00:00             No              NaN        Yes
# 4  2014-07-01 00:00:00             No              NaN         No
#
#          Application Date License Issued Date License Expired Date
# 0 2014-09-12 13:13:36.713          2014-09-12           2019-09-12
# 1 2014-09-12 15:26:51.417          2014-09-12           2017-10-20
# 2 2014-09-12 15:43:17.707          2014-09-12           2019-09-12
# 3 2014-09-12 16:14:48.487          2014-09-12           2017-09-12
# 4 2014-09-12 16:22:54.113          2014-09-12           2017-09-12

# %%
dogsum = datadog.groupby('Owner Zip Code').count().sort_values(by = 'Animal Name', ascending=False)['Animal Name']

# %%
dogsum = dogsum.reset_index()

# %%
dogsum.columns = ['postalCode', 'Number of Dogs']

# %%
dogsum.head()
# Out:
#    postalCode  Number of Dogs
# 0       10025            2072
# 1       10023            1646
# 2       10024            1644
# 3       10011            1554
# 4       10128            1474

# %%
type(dogsum['postalCode'][0])
# Out:
# numpy.int64

# %%
zipcodes = gpd.GeoDataFrame.from_file('NYCZIPS.geojson')

# %%
zipcodes.head()
# Out:
#                                                  @id  BLDGpostal CTY_FIPS  \
# 0  http://nyc.pediacities.com/Resource/PostalCode...           0      081
# 1  http://nyc.pediacities.com/Resource/PostalCode...           0      081
# 2  http://nyc.pediacities.com/Resource/PostalCode...           0      081
# 3  http://nyc.pediacities.com/Resource/PostalCode...           0      081
# 4  http://nyc.pediacities.com/Resource/PostalCode...           0      081
#
#    OBJECTID          PO_NAME STATE ST_FIPS borough  \
# 0         1  Jackson Heights    NY      36  Queens
# 1         2        Glen Oaks    NY      36  Queens
# 2         3    New Hyde Park    NY      36  Queens
# 3         4        Bellerose    NY      36  Queens
# 4         5    Fresh Meadows    NY      36  Queens
#
#                                             geometry   latitude  longitude  \
# 0  POLYGON ((-73.86942457284177 40.74915687096788...  40.751662 -73.883573
# 1  POLYGON ((-73.71132911125308 40.74947450816085...  40.745366 -73.711608
# 2  POLYGON ((-73.70098278625547 40.73889569923034...  40.748714 -73.703443
# 3  POLYGON ((-73.72270447144122 40.75373371438336...  40.736534 -73.724004
# 4  POLYGON ((-73.81088634744756 40.7271718757592,...  40.739903 -73.794626
#
#   postalCode
# 0      11372
# 1      11004
# 2      11040
# 3      11426
# 4      11365

# %%
zipcodes.crs
# Out:
# {'init': u'epsg:4326'}

# %%
zipcodes = zipcodes.to_crs(epsg=3395)

# %%
zipcodes.plot(alpha=0, figsize = (12,10))

# %%
len(dogsum)
# Out:
# 298

# %%
len(zipcodes)
# Out:
# 262

# %%
zipcodes['postalCode'] = zipcodes['postalCode'].astype(int)

# %%
geodosgum = pd.merge(zipcodes, dogsum, on= 'postalCode')

# %%
len(geodosgum)
# Out:
# 204

# %%
geodosgum.head()
# Out:
#                                                  @id  BLDGpostal CTY_FIPS  \
# 0  http://nyc.pediacities.com/Resource/PostalCode...           0      081
# 1  http://nyc.pediacities.com/Resource/PostalCode...           0      081
# 2  http://nyc.pediacities.com/Resource/PostalCode...           0      081
# 3  http://nyc.pediacities.com/Resource/PostalCode...           0      081
# 4  http://nyc.pediacities.com/Resource/PostalCode...           0      081
#
#    OBJECTID          PO_NAME STATE ST_FIPS borough  \
# 0         1  Jackson Heights    NY      36  Queens
# 1         2        Glen Oaks    NY      36  Queens
# 2         3    New Hyde Park    NY      36  Queens
# 3         4        Bellerose    NY      36  Queens
# 4         5    Fresh Meadows    NY      36  Queens
#
#                                             geometry   latitude  longitude  \
# 0  POLYGON ((-8223106.728640875 4947515.078433569...  40.751662 -73.883573
# 1  POLYGON ((-8205507.622360095 4947561.572938457...  40.745366 -73.711608
# 2  POLYGON ((-8204355.87472978 4946013.208139954,...  40.748714 -73.703443
# 3  POLYGON ((-8206773.921663828 4948185.040709085...  40.736534 -73.724004
# 4  POLYGON ((-8216590.283198051 4944297.543410451...  40.739903 -73.794626
#
#    postalCode  Number of Dogs
# 0       11372             550
# 1       11004             180
# 2       11040              23
# 3       11426             187
# 4       11365             362

# %%
plt.figure()
geodosgum.plot(column='Number of Dogs', alpha=0.8, scheme = 'QUANTILES', k=8, colormap='Blues', figsize = (12,12), legend=True)
plt.grid()
plt.title("Total number of licensed dogs per zipcode - May 2016 - NYC", fontsize=20)

# %%
geodosgum['Zipcode Area']= geodosgum.area

# %%
geodosgum['Dog Density']= geodosgum['Number of Dogs']/geodosgum['Zipcode Area']

# %%
plt.figure()
geodosgum.plot(column='Dog Density', alpha=0.7, scheme = 'QUANTILES', k=8, colormap='Reds', figsize = (12,12), legend=True)
plt.title("Density of licensed dogs per zipcode - May 2016 - NYC (Dogs x sqr mile)", fontsize=20)
plt.grid()
